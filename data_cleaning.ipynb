# %%
# Only run if you need spotipy to pull from Spotify API


import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
import numpy as np
import pandas as pd

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# # Code to Pull Data from API

# %%
#Authentication - without user
cid = ""
secret = "" 

## you will need to use the spotify keys generated for ur account
## log in to spotify for developers using ur spotify acc
## and go the "dashboard", create new app
## and then it should give you a client key/ID and a secret key/ID to use here


client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
data = pd.read_csv("muse_v3.csv")

# pull relevant columns from original dataset (MuseV3) and drop entres w/o spotify_id entries
data = data.loc[:,["track", "artist","seeds", "spotify_id"]]
data = data.dropna(subset=["spotify_id"])
data = data.reset_index(drop=True)

# print(data.loc[36463])
# print(data.loc[53048])
# print(data.loc[53049])

# drop outlying entries that give invalid spotify_id
data = data.drop([36463, 53048, 53049], axis=0)
data = data.reset_index(drop=True)

spotify_URIs = data.loc[:,"spotify_id"]

data.to_csv("cleaned.csv")
# Out:
# track                The Worst Thing
# artist              Natalie Merchant
# seeds                    ['sensual']
# spotify_id    1oxGZTK9dJsxGFFQg5Bp4A
# Name: 36463, dtype: object
# track          Duo: Stabat Mater dolorosa
# artist        Giovanni Battista Pergolesi
# seeds                          ['sacred']
# spotify_id         03XXOqmlkcR7m09uiBnJXA
# Name: 53048, dtype: object
# track         Duo: O quam tristis et afflicta
# artist            Giovanni Battista Pergolesi
# seeds                              ['sacred']
# spotify_id             7oOrKaeaN9TILjfVW0Nesq
# Name: 53049, dtype: object

# %%
num_tracks = len(spotify_URIs)
print(num_tracks)

# pull audio features from Spotify API 100 at a time

audio_features = sp.audio_features(tracks=spotify_URIs[:100])
audio_data = pd.DataFrame(audio_features)
for i in range(100, num_tracks, 100): 
    if (i >= 61600):
        audio_features = sp.audio_features(tracks=spotify_URIs[i:])
        print(i)
        print("LAST")
    else:
        audio_features = sp.audio_features(tracks=spotify_URIs[i:i+100])

    more_data = pd.DataFrame(audio_features)

    audio_data = pd.concat((audio_data, more_data), axis=0)

    print(audio_data)
# Out:
# 61627
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.548   0.847    1    -3.237     1       0.1860      0.062200
# 1          0.249   0.949    2    -2.642     0       0.0678      0.001310
# 2          0.668   0.787    1    -4.226     1       0.0429      0.109000
# 3          0.805   0.918    9    -4.554     1       0.2120      0.049300
# 4          0.657   0.960    5    -3.524     0       0.0700      0.001690
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.511   0.961    7    -4.450     0       0.0651      0.000064
# 96         0.827   0.676    7    -9.735     1       0.2620      0.025700
# 97         0.817   0.658    2    -6.212     1       0.3060      0.108000
# 98         0.361   0.871   10    -4.821     0       0.3100      0.001190
# 99         0.210   0.841    1    -5.676     0       0.0715      0.000227
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.000000    0.0816    0.100  171.447  audio_features
# 1           0.022800    0.0953    0.498  185.252  audio_features
# 2           0.000000    0.2100    0.478  100.059  audio_features
# 3           0.000000    0.0691    0.713  125.984  audio_features
# 4           0.000997    0.1090    0.567  126.020  audio_features
# ..               ...       ...      ...      ...             ...
# 95          0.462000    0.0924    0.285  100.043  audio_features
# 96          0.000005    0.0790    0.792   97.835  audio_features
# 97          0.000000    0.1150    0.393   91.992  audio_features
# 98          0.000000    0.3210    0.705  176.709  audio_features
# 99          0.000349    0.0688    0.390  182.416  audio_features
#
#                         id                                   uri  \
# 0   4xkOaSrkexMciUUogZKVTS  spotify:track:4xkOaSrkexMciUUogZKVTS
# 1   3fOc9x06lKJBhz435mInlH  spotify:track:3fOc9x06lKJBhz435mInlH
# 2   3Y96xd4Ce0J47dcalLrEC8  spotify:track:3Y96xd4Ce0J47dcalLrEC8
# 3   6tqFC1DIOphJkCwrjVzPmg  spotify:track:6tqFC1DIOphJkCwrjVzPmg
# 4   5bU4KX47KqtDKKaLM4QCzh  spotify:track:5bU4KX47KqtDKKaLM4QCzh
# ..                     ...                                   ...
# 95  1yCZLoVKku8xK62cv11b4u  spotify:track:1yCZLoVKku8xK62cv11b4u
# 96  7ygrDIOwwM4gtNf8Pz6kxW  spotify:track:7ygrDIOwwM4gtNf8Pz6kxW
# 97  3dO8wIpOvPLnek2Dt4SJ3V  spotify:track:3dO8wIpOvPLnek2Dt4SJ3V
# 98  0x7sG0x7hibf4o2YP9D7C3  spotify:track:0x7sG0x7hibf4o2YP9D7C3
# 99  6gcgaudbKHYgFgQaeCPwYU  spotify:track:6gcgaudbKHYgFgQaeCPwYU
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/4xkOaSrkexMc...
# 1   https://api.spotify.com/v1/tracks/3fOc9x06lKJB...
# 2   https://api.spotify.com/v1/tracks/3Y96xd4Ce0J4...
# 3   https://api.spotify.com/v1/tracks/6tqFC1DIOphJ...
# 4   https://api.spotify.com/v1/tracks/5bU4KX47KqtD...
# ..                                                ...
# 95  https://api.spotify.com/v1/tracks/1yCZLoVKku8x...
# 96  https://api.spotify.com/v1/tracks/7ygrDIOwwM4g...
# 97  https://api.spotify.com/v1/tracks/3dO8wIpOvPLn...
# 98  https://api.spotify.com/v1/tracks/0x7sG0x7hibf...
# 99  https://api.spotify.com/v1/tracks/6gcgaudbKHYg...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/4xkO...       297787
# 1   https://api.spotify.com/v1/audio-analysis/3fOc...       441133
# 2   https://api.spotify.com/v1/audio-analysis/3Y96...       204960
# 3   https://api.spotify.com/v1/audio-analysis/6tqF...       298360
# 4   https://api.spotify.com/v1/audio-analysis/5bU4...       186067
# ..                                                ...          ...
# 95  https://api.spotify.com/v1/audio-analysis/1yCZ...       316920
# 96  https://api.spotify.com/v1/audio-analysis/7ygr...       182160
# 97  https://api.spotify.com/v1/audio-analysis/3dO8...       206587
# 98  https://api.spotify.com/v1/audio-analysis/0x7s...       240267
# 99  https://api.spotify.com/v1/audio-analysis/6gcg...       240520
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# ..             ...
# 95               4
# 96               4
# 97               4
# 98               4
# 99               3
#
# [200 rows x 18 columns]
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.548   0.847    1    -3.237     1       0.1860      0.062200
# 1          0.249   0.949    2    -2.642     0       0.0678      0.001310
# 2          0.668   0.787    1    -4.226     1       0.0429      0.109000
# 3          0.805   0.918    9    -4.554     1       0.2120      0.049300
# 4          0.657   0.960    5    -3.524     0       0.0700      0.001690
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.326   0.930    0    -4.473     0       0.1110      0.000011
# 96         0.426   0.982    5    -3.022     0       0.1210      0.000006
# 97         0.333   0.992   10    -4.198     0       0.1610      0.000004
# 98         0.217   0.770    8    -5.776     0       0.0373      0.038400
# 99         0.340   0.998    0    -2.909     1       0.2090      0.000065
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.000000    0.0816    0.100  171.447  audio_features
# 1           0.022800    0.0953    0.498  185.252  audio_features
# 2           0.000000    0.2100    0.478  100.059  audio_features
# 3           0.000000    0.0691    0.713  125.984  audio_features
# 4           0.000997    0.1090    0.567  126.020  audio_features
# ..               ...       ...      ...      ...             ...
# 95          0.125000    0.3030    0.372  182.169  audio_features
# 96          0.902000    0.1930    0.227  146.068  audio_features
# 97          0.306000    0.2750    0.262  198.038  audio_features
# 98          0.000465    0.5540    0.582  166.211  audio_features
# 99          0.000780    0.2500    0.116  160.678  audio_features
#
#                         id                                   uri  \
# 0   4xkOaSrkexMciUUogZKVTS  spotify:track:4xkOaSrkexMciUUogZKVTS
# 1   3fOc9x06lKJBhz435mInlH  spotify:track:3fOc9x06lKJBhz435mInlH
# 2   3Y96xd4Ce0J47dcalLrEC8  spotify:track:3Y96xd4Ce0J47dcalLrEC8
# 3   6tqFC1DIOphJkCwrjVzPmg  spotify:track:6tqFC1DIOphJkCwrjVzPmg
# 4   5bU4KX47KqtDKKaLM4QCzh  spotify:track:5bU4KX47KqtDKKaLM4QCzh
# ..                     ...                                   ...
# 95  3UJyOgofFfi8nfG8lgdiOX  spotify:track:3UJyOgofFfi8nfG8lgdiOX
# 96  2Z50i8tkAi8EK9i3DdqReI  spotify:track:2Z50i8tkAi8EK9i3DdqReI
# 97  6bkshQZTB2QGfy7MN3yhGY  spotify:track:6bkshQZTB2QGfy7MN3yhGY
# 98  4OZLL39ISzW2rgF1SE32SG  spotify:track:4OZLL39ISzW2rgF1SE32SG
# 99  7vNiCVFghw336cXSXVqiGG  spotify:track:7vNiCVFghw336cXSXVqiGG
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/4xkOaSrkexMc...
# 1   https://api.spotify.com/v1/tracks/3fOc9x06lKJB...
# 2   https://api.spotify.com/v1/tracks/3Y96xd4Ce0J4...
# 3   https://api.spotify.com/v1/tracks/6tqFC1DIOphJ...
# 4   https://api.spotify.com/v1/tracks/5bU4KX47KqtD...
# ..                                                ...
# 95  https://api.spotify.com/v1/tracks/3UJyOgofFfi8...
# 96  https://api.spotify.com/v1/tracks/2Z50i8tkAi8E...
# 97  https://api.spotify.com/v1/tracks/6bkshQZTB2QG...
# 98  https://api.spotify.com/v1/tracks/4OZLL39ISzW2...
# 99  https://api.spotify.com/v1/tracks/7vNiCVFghw33...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/4xkO...       297787
# 1   https://api.spotify.com/v1/audio-analysis/3fOc...       441133
# 2   https://api.spotify.com/v1/audio-analysis/3Y96...       204960
# 3   https://api.spotify.com/v1/audio-analysis/6tqF...       298360
# 4   https://api.spotify.com/v1/audio-analysis/5bU4...       186067
# ..                                                ...          ...
# 95  https://api.spotify.com/v1/audio-analysis/3UJy...       202827
# 96  https://api.spotify.com/v1/audio-analysis/2Z50...       287307
# 97  https://api.spotify.com/v1/audio-analysis/6bks...       416507
# 98  https://api.spotify.com/v1/audio-analysis/4OZL...       214667
# 99  https://api.spotify.com/v1/audio-analysis/7vNi...       236587
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# ..             ...
# 95               4
# 96               4
# 97               4
# 98               3
# 99               4
#
# [300 rows x 18 columns]
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.548   0.847    1    -3.237     1       0.1860      0.062200
# 1          0.249   0.949    2    -2.642     0       0.0678      0.001310
# 2          0.668   0.787    1    -4.226     1       0.0429      0.109000
# 3          0.805   0.918    9    -4.554     1       0.2120      0.049300
# 4          0.657   0.960    5    -3.524     0       0.0700      0.001690
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.372   0.912    9    -8.832     0       0.0713      0.001630
# 96         0.224   0.962    8    -6.849     1       0.1840      0.000093
# 97         0.570   0.273    4   -14.050     1       0.0887      0.627000
# 98         0.485   0.823   11    -7.921     0       0.0355      0.000041
# 99         0.522   0.984    1    -5.600     1       0.0546      0.000175
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.000000    0.0816    0.100  171.447  audio_features
# 1           0.022800    0.0953    0.498  185.252  audio_features
# 2           0.000000    0.2100    0.478  100.059  audio_features
# 3           0.000000    0.0691    0.713  125.984  audio_features
# 4           0.000997    0.1090    0.567  126.020  audio_features
# ..               ...       ...      ...      ...             ...
# 95          0.027500    0.2970    0.459  166.889  audio_features
# 96          0.015600    0.0928    0.100  156.030  audio_features
# 97          0.000000    0.1940    0.477  124.660  audio_features
# 98          0.000247    0.1630    0.872   88.397  audio_features
# 99          0.598000    0.0980    0.413  134.999  audio_features
#
#                         id                                   uri  \
# 0   4xkOaSrkexMciUUogZKVTS  spotify:track:4xkOaSrkexMciUUogZKVTS
# 1   3fOc9x06lKJBhz435mInlH  spotify:track:3fOc9x06lKJBhz435mInlH
# 2   3Y96xd4Ce0J47dcalLrEC8  spotify:track:3Y96xd4Ce0J47dcalLrEC8
# 3   6tqFC1DIOphJkCwrjVzPmg  spotify:track:6tqFC1DIOphJkCwrjVzPmg
# 4   5bU4KX47KqtDKKaLM4QCzh  spotify:track:5bU4KX47KqtDKKaLM4QCzh
# ..                     ...                                   ...
# 95  3aKhLm5mONfAtS1NZXG8f4  spotify:track:3aKhLm5mONfAtS1NZXG8f4
# 96  2BrozLWEthSUJn3Mhi2SL6  spotify:track:2BrozLWEthSUJn3Mhi2SL6
# 97  4YvDviJWcOokkv38g2ICHi  spotify:track:4YvDviJWcOokkv38g2ICHi
# 98  2SPx20zLcydVe85iEgLuIG  spotify:track:2SPx20zLcydVe85iEgLuIG
# 99  1IyjDMrsUZxIhHttM3FSGY  spotify:track:1IyjDMrsUZxIhHttM3FSGY
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/4xkOaSrkexMc...
# 1   https://api.spotify.com/v1/tracks/3fOc9x06lKJB...
# 2   https://api.spotify.com/v1/tracks/3Y96xd4Ce0J4...
# 3   https://api.spotify.com/v1/tracks/6tqFC1DIOphJ...
# 4   https://api.spotify.com/v1/tracks/5bU4KX47KqtD...
# ..                                                ...
# 95  https://api.spotify.com/v1/tracks/3aKhLm5mONfA...
# 96  https://api.spotify.com/v1/tracks/2BrozLWEthSU...
# 97  https://api.spotify.com/v1/tracks/4YvDviJWcOok...
# 98  https://api.spotify.com/v1/tracks/2SPx20zLcydV...
# 99  https://api.spotify.com/v1/tracks/1IyjDMrsUZxI...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/4xkO...       297787
# 1   https://api.spotify.com/v1/audio-analysis/3fOc...       441133
# 2   https://api.spotify.com/v1/audio-analysis/3Y96...       204960
# 3   https://api.spotify.com/v1/audio-analysis/6tqF...       298360
# 4   https://api.spotify.com/v1/audio-analysis/5bU4...       186067
# ..                                                ...          ...
# 95  https://api.spotify.com/v1/audio-analysis/3aKh...       444453
# 96  https://api.spotify.com/v1/audio-analysis/2Bro...       335200
# 97  https://api.spotify.com/v1/audio-analysis/4YvD...       152213
# 98  https://api.spotify.com/v1/audio-analysis/2SPx...       153133
# 99  https://api.spotify.com/v1/audio-analysis/1Iyj...       282880
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# ..             ...
# 95               4
# 96               3
# 97               4
# 98               4
# 99               4
#
# [400 rows x 18 columns]
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.548   0.847    1    -3.237     1       0.1860      0.062200
# 1          0.249   0.949    2    -2.642     0       0.0678      0.001310
# 2          0.668   0.787    1    -4.226     1       0.0429      0.109000
# 3          0.805   0.918    9    -4.554     1       0.2120      0.049300
# 4          0.657   0.960    5    -3.524     0       0.0700      0.001690
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.181   0.945    5   -10.114     0       0.1770      0.000036
# 96         0.211   0.930    2   -13.076     1       0.1900      0.049200
# 97         0.744   0.675    9    -7.630     1       0.0603      0.008010
# 98         0.433   0.957    7    -4.588     1       0.0508      0.000800
# 99         0.282   0.995    7    -3.485     1       0.2050      0.000100
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.000000    0.0816   0.1000  171.447  audio_features
# 1           0.022800    0.0953   0.4980  185.252  audio_features
# 2           0.000000    0.2100   0.4780  100.059  audio_features
# 3           0.000000    0.0691   0.7130  125.984  audio_features
# 4           0.000997    0.1090   0.5670  126.020  audio_features
# ..               ...       ...      ...      ...             ...
# 95          0.747000    0.0750   0.1410  169.533  audio_features
# 96          0.885000    0.1820   0.0936  157.479  audio_features
# 97          0.164000    0.1370   0.6680  116.016  audio_features
# 98          0.000776    0.4140   0.1990  144.996  audio_features
# 99          0.000013    0.5730   0.0842  107.123  audio_features
#
#                         id                                   uri  \
# 0   4xkOaSrkexMciUUogZKVTS  spotify:track:4xkOaSrkexMciUUogZKVTS
# 1   3fOc9x06lKJBhz435mInlH  spotify:track:3fOc9x06lKJBhz435mInlH
# 2   3Y96xd4Ce0J47dcalLrEC8  spotify:track:3Y96xd4Ce0J47dcalLrEC8
# 3   6tqFC1DIOphJkCwrjVzPmg  spotify:track:6tqFC1DIOphJkCwrjVzPmg
# 4   5bU4KX47KqtDKKaLM4QCzh  spotify:track:5bU4KX47KqtDKKaLM4QCzh
# ..                     ...                                   ...
# 95  25Q6sQbwgrsCYYugn0Ymrb  spotify:track:25Q6sQbwgrsCYYugn0Ymrb
# 96  260eHV0hZ5hWAL0LC6NJaW  spotify:track:260eHV0hZ5hWAL0LC6NJaW
# 97  6SEWg79MIOSWXaMIOGWdwm  spotify:track:6SEWg79MIOSWXaMIOGWdwm
# 98  2N3ljzwU26IoKhbWml4MRL  spotify:track:2N3ljzwU26IoKhbWml4MRL
# 99  0C8Mr7G9cSubSmCCILELM6  spotify:track:0C8Mr7G9cSubSmCCILELM6
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/4xkOaSrkexMc...
# 1   https://api.spotify.com/v1/tracks/3fOc9x06lKJB...
# 2   https://api.spotify.com/v1/tracks/3Y96xd4Ce0J4...
# 3   https://api.spotify.com/v1/tracks/6tqFC1DIOphJ...
# 4   https://api.spotify.com/v1/tracks/5bU4KX47KqtD...
# ..                                                ...
# 95  https://api.spotify.com/v1/tracks/25Q6sQbwgrsC...
# 96  https://api.spotify.com/v1/tracks/260eHV0hZ5hW...
# 97  https://api.spotify.com/v1/tracks/6SEWg79MIOSW...
# 98  https://api.spotify.com/v1/tracks/2N3ljzwU26Io...
# 99  https://api.spotify.com/v1/tracks/0C8Mr7G9cSub...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/4xkO...       297787
# 1   https://api.spotify.com/v1/audio-analysis/3fOc...       441133
# 2   https://api.spotify.com/v1/audio-analysis/3Y96...       204960
# 3   https://api.spotify.com/v1/audio-analysis/6tqF...       298360
# 4   https://api.spotify.com/v1/audio-analysis/5bU4...       186067
# ..                                                ...          ...
# 95  https://api.spotify.com/v1/audio-analysis/25Q6...       218587
# 96  https://api.spotify.com/v1/audio-analysis/260e...       213840
# 97  https://api.spotify.com/v1/audio-analysis/6SEW...       325172
# 98  https://api.spotify.com/v1/audio-analysis/2N3l...       225320
# 99  https://api.spotify.com/v1/audio-analysis/0C8M...       325973
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# ..             ...
# 95               4
# 96               4
# 97               4
# 98               3
# 99               4
#
# [500 rows x 18 columns]
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.548   0.847    1    -3.237     1       0.1860      0.062200
# 1          0.249   0.949    2    -2.642     0       0.0678      0.001310
# 2          0.668   0.787    1    -4.226     1       0.0429      0.109000
# 3          0.805   0.918    9    -4.554     1       0.2120      0.049300
# 4          0.657   0.960    5    -3.524     0       0.0700      0.001690
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.452   0.628    9   -10.079     0       0.0795      0.204000
# 96         0.423   0.706    9    -8.944     0       0.0434      0.000577
# 97         0.138   0.932   11    -5.011     1       0.2660      0.149000
# 98         0.458   0.870    7    -5.629     1       0.0552      0.000297
# 99         0.657   0.814    7    -5.153     1       0.0332      0.029000
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.000000    0.0816    0.100  171.447  audio_features
# 1           0.022800    0.0953    0.498  185.252  audio_features
# 2           0.000000    0.2100    0.478  100.059  audio_features
# 3           0.000000    0.0691    0.713  125.984  audio_features
# 4           0.000997    0.1090    0.567  126.020  audio_features
# ..               ...       ...      ...      ...             ...
# 95          0.040400    0.1760    0.149  107.935  audio_features
# 96          0.018800    0.1610    0.901   83.554  audio_features
# 97          0.000117    0.8130    0.039  158.397  audio_features
# 98          0.000047    0.1200    0.395  180.062  audio_features
# 99          0.000000    0.0618    0.725  130.010  audio_features
#
#                         id                                   uri  \
# 0   4xkOaSrkexMciUUogZKVTS  spotify:track:4xkOaSrkexMciUUogZKVTS
# 1   3fOc9x06lKJBhz435mInlH  spotify:track:3fOc9x06lKJBhz435mInlH
# 2   3Y96xd4Ce0J47dcalLrEC8  spotify:track:3Y96xd4Ce0J47dcalLrEC8
# 3   6tqFC1DIOphJkCwrjVzPmg  spotify:track:6tqFC1DIOphJkCwrjVzPmg
# 4   5bU4KX47KqtDKKaLM4QCzh  spotify:track:5bU4KX47KqtDKKaLM4QCzh
# ..                     ...                                   ...
# 95  39joJYPewGDDlU7q1hWPsS  spotify:track:39joJYPewGDDlU7q1hWPsS
# 96  0QxAAxJKgsV8AH6T1L7vtc  spotify:track:0QxAAxJKgsV8AH6T1L7vtc
# 97  1zHr34Ekz2lffG6rhJbalO  spotify:track:1zHr34Ekz2lffG6rhJbalO
# 98  7o8SksWtkdHaI1hLniokXZ  spotify:track:7o8SksWtkdHaI1hLniokXZ
# 99  6wNajOmhYbtemZQjXsBU6k  spotify:track:6wNajOmhYbtemZQjXsBU6k
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/4xkOaSrkexMc...
# 1   https://api.spotify.com/v1/tracks/3fOc9x06lKJB...
# 2   https://api.spotify.com/v1/tracks/3Y96xd4Ce0J4...
# 3   https://api.spotify.com/v1/tracks/6tqFC1DIOphJ...
# 4   https://api.spotify.com/v1/tracks/5bU4KX47KqtD...
# ..                                                ...
# 95  https://api.spotify.com/v1/tracks/39joJYPewGDD...
# 96  https://api.spotify.com/v1/tracks/0QxAAxJKgsV8...
# 97  https://api.spotify.com/v1/tracks/1zHr34Ekz2lf...
# 98  https://api.spotify.com/v1/tracks/7o8SksWtkdHa...
# 99  https://api.spotify.com/v1/tracks/6wNajOmhYbte...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/4xkO...       297787
# 1   https://api.spotify.com/v1/audio-analysis/3fOc...       441133
# 2   https://api.spotify.com/v1/audio-analysis/3Y96...       204960
# 3   https://api.spotify.com/v1/audio-analysis/6tqF...       298360
# 4   https://api.spotify.com/v1/audio-analysis/5bU4...       186067
# ..                                                ...          ...
# 95  https://api.spotify.com/v1/audio-analysis/39jo...       323493
# 96  https://api.spotify.com/v1/audio-analysis/0QxA...       137173
# 97  https://api.spotify.com/v1/audio-analysis/1zHr...       148493
# 98  https://api.spotify.com/v1/audio-analysis/7o8S...       264173
# 99  https://api.spotify.com/v1/audio-analysis/6wNa...       175040
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# ..             ...
# 95               4
# 96               4
# 97               4
# 98               4
# 99               4
#
# [600 rows x 18 columns]
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.548   0.847    1    -3.237     1       0.1860      0.062200
# 1          0.249   0.949    2    -2.642     0       0.0678      0.001310
# 2          0.668   0.787    1    -4.226     1       0.0429      0.109000
# 3          0.805   0.918    9    -4.554     1       0.2120      0.049300
# 4          0.657   0.960    5    -3.524     0       0.0700      0.001690
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.665   0.554    7   -21.269     0       0.4950      0.995000
# 96         0.167   0.785    0    -5.621     1       0.0551      0.869000
# 97         0.438   0.959    7    -6.551     1       0.0467      0.000005
# 98         0.331   0.838    5    -3.906     0       0.0262      0.002820
# 99         0.464   0.980    9    -6.493     0       0.2550      0.000047
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.000000    0.0816   0.1000  171.447  audio_features
# 1           0.022800    0.0953   0.4980  185.252  audio_features
# 2           0.000000    0.2100   0.4780  100.059  audio_features
# 3           0.000000    0.0691   0.7130  125.984  audio_features
# 4           0.000997    0.1090   0.5670  126.020  audio_features
# ..               ...       ...      ...      ...             ...
# 95          0.222000    0.2990   0.0468  109.061  audio_features
# 96          0.843000    0.1480   0.0397  128.241  audio_features
# 97          0.097300    0.1910   0.8050  139.988  audio_features
# 98          0.000755    0.1750   0.2390  106.598  audio_features
# 99          0.049900    0.3550   0.1640  137.048  audio_features
#
#                         id                                   uri  \
# 0   4xkOaSrkexMciUUogZKVTS  spotify:track:4xkOaSrkexMciUUogZKVTS
# 1   3fOc9x06lKJBhz435mInlH  spotify:track:3fOc9x06lKJBhz435mInlH
# 2   3Y96xd4Ce0J47dcalLrEC8  spotify:track:3Y96xd4Ce0J47dcalLrEC8
# 3   6tqFC1DIOphJkCwrjVzPmg  spotify:track:6tqFC1DIOphJkCwrjVzPmg
# 4   5bU4KX47KqtDKKaLM4QCzh  spotify:track:5bU4KX47KqtDKKaLM4QCzh
# ..                     ...                                   ...
# 95  3AEaktKiPVaCqioQ40nqSQ  spotify:track:3AEaktKiPVaCqioQ40nqSQ
# 96  1suL3huzAGeUnkd6FbDedK  spotify:track:1suL3huzAGeUnkd6FbDedK
# 97  1J6hMtJT298mbMbpjTbUnE  spotify:track:1J6hMtJT298mbMbpjTbUnE
# 98  5XzmLcZ3vzEWe5UoCAel0p  spotify:track:5XzmLcZ3vzEWe5UoCAel0p
# 99  4P6ByTNMRoPQlCGEGun3Iz  spotify:track:4P6ByTNMRoPQlCGEGun3Iz
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/4xkOaSrkexMc...
# 1   https://api.spotify.com/v1/tracks/3fOc9x06lKJB...
# 2   https://api.spotify.com/v1/tracks/3Y96xd4Ce0J4...
# 3   https://api.spotify.com/v1/tracks/6tqFC1DIOphJ...
# 4   https://api.spotify.com/v1/tracks/5bU4KX47KqtD...
# ..                                                ...
# 95  https://api.spotify.com/v1/tracks/3AEaktKiPVaC...
# 96  https://api.spotify.com/v1/tracks/1suL3huzAGeU...
# 97  https://api.spotify.com/v1/tracks/1J6hMtJT298m...
# 98  https://api.spotify.com/v1/tracks/5XzmLcZ3vzEW...
# 99  https://api.spotify.com/v1/tracks/4P6ByTNMRoPQ...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/4xkO...       297787
# 1   https://api.spotify.com/v1/audio-analysis/3fOc...       441133
# 2   https://api.spotify.com/v1/audio-analysis/3Y96...       204960
# 3   https://api.spotify.com/v1/audio-analysis/6tqF...       298360
# 4   https://api.spotify.com/v1/audio-analysis/5bU4...       186067
# ..                                                ...          ...
# 95  https://api.spotify.com/v1/audio-analysis/3AEa...        43040
# 96  https://api.spotify.com/v1/audio-analysis/1suL...       431653
# 97  https://api.spotify.com/v1/audio-analysis/1J6h...       341867
# 98  https://api.spotify.com/v1/audio-analysis/5Xzm...       320800
# 99  https://api.spotify.com/v1/audio-analysis/4P6B...       236093
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# ..             ...
# 95               5
# 96               3
# 97               4
# 98               3
# 99               4
#
# [700 rows x 18 columns]
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.548   0.847    1    -3.237     1       0.1860      0.062200
# 1          0.249   0.949    2    -2.642     0       0.0678      0.001310
# 2          0.668   0.787    1    -4.226     1       0.0429      0.109000
# 3          0.805   0.918    9    -4.554     1       0.2120      0.049300
# 4          0.657   0.960    5    -3.524     0       0.0700      0.001690
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.734   0.935    1    -5.974     1       0.0774      0.003880
# 96         0.441   0.954    9    -4.461     0       0.1930      0.000200
# 97         0.377   0.976   10    -5.314     1       0.0944      0.088900
# 98         0.552   0.969    1    -3.753     1       0.0475      0.000804
# 99         0.495   0.886    8    -5.444     0       0.0596      0.000326
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.000000    0.0816   0.1000  171.447  audio_features
# 1           0.022800    0.0953   0.4980  185.252  audio_features
# 2           0.000000    0.2100   0.4780  100.059  audio_features
# 3           0.000000    0.0691   0.7130  125.984  audio_features
# 4           0.000997    0.1090   0.5670  126.020  audio_features
# ..               ...       ...      ...      ...             ...
# 95          0.084000    0.3340   0.3000   95.012  audio_features
# 96          0.000000    0.4900   0.3770  170.025  audio_features
# 97          0.981000    0.1730   0.1060  132.694  audio_features
# 98          0.077600    0.1120   0.0364  126.936  audio_features
# 99          0.009650    0.1330   0.3260  112.863  audio_features
#
#                         id                                   uri  \
# 0   4xkOaSrkexMciUUogZKVTS  spotify:track:4xkOaSrkexMciUUogZKVTS
# 1   3fOc9x06lKJBhz435mInlH  spotify:track:3fOc9x06lKJBhz435mInlH
# 2   3Y96xd4Ce0J47dcalLrEC8  spotify:track:3Y96xd4Ce0J47dcalLrEC8
# 3   6tqFC1DIOphJkCwrjVzPmg  spotify:track:6tqFC1DIOphJkCwrjVzPmg
# 4   5bU4KX47KqtDKKaLM4QCzh  spotify:track:5bU4KX47KqtDKKaLM4QCzh
# ..                     ...                                   ...
# 95  7lZINvSLY5aFcp9cdLGa39  spotify:track:7lZINvSLY5aFcp9cdLGa39
# 96  4HheguzMvKnZGd9y55Xvbt  spotify:track:4HheguzMvKnZGd9y55Xvbt
# 97  4XXyLxSFVLwj9Ah3TeUcrM  spotify:track:4XXyLxSFVLwj9Ah3TeUcrM
# 98  0AAA6bPZPHJVp3XLyk2jNo  spotify:track:0AAA6bPZPHJVp3XLyk2jNo
# 99  7lpy15bX1a91G7DeASMaWs  spotify:track:7lpy15bX1a91G7DeASMaWs
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/4xkOaSrkexMc...
# 1   https://api.spotify.com/v1/tracks/3fOc9x06lKJB...
# 2   https://api.spotify.com/v1/tracks/3Y96xd4Ce0J4...
# 3   https://api.spotify.com/v1/tracks/6tqFC1DIOphJ...
# 4   https://api.spotify.com/v1/tracks/5bU4KX47KqtD...
# ..                                                ...
# 95  https://api.spotify.com/v1/tracks/7lZINvSLY5aF...
# 96  https://api.spotify.com/v1/tracks/4HheguzMvKnZ...
# 97  https://api.spotify.com/v1/tracks/4XXyLxSFVLwj...
# 98  https://api.spotify.com/v1/tracks/0AAA6bPZPHJV...
# 99  https://api.spotify.com/v1/tracks/7lpy15bX1a91...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/4xkO...       297787
# 1   https://api.spotify.com/v1/audio-analysis/3fOc...       441133
# 2   https://api.spotify.com/v1/audio-analysis/3Y96...       204960
# 3   https://api.spotify.com/v1/audio-analysis/6tqF...       298360
# 4   https://api.spotify.com/v1/audio-analysis/5bU4...       186067
# ..                                                ...          ...
# 95  https://api.spotify.com/v1/audio-analysis/7lZI...       136747
# 96  https://api.spotify.com/v1/audio-analysis/4Hhe...       227647
# 97  https://api.spotify.com/v1/audio-analysis/4XXy...       151347
# 98  https://api.spotify.com/v1/audio-analysis/0AAA...       248400
# 99  https://api.spotify.com/v1/audio-analysis/7lpy...       219867
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# ..             ...
# 95               4
# 96               4
# 97               4
# 98               4
# 99               4
#
# [800 rows x 18 columns]
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.548   0.847    1    -3.237     1       0.1860      0.062200
# 1          0.249   0.949    2    -2.642     0       0.0678      0.001310
# 2          0.668   0.787    1    -4.226     1       0.0429      0.109000
# 3          0.805   0.918    9    -4.554     1       0.2120      0.049300
# 4          0.657   0.960    5    -3.524     0       0.0700      0.001690
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.248   0.940    4    -4.235     1       0.3120      0.001790
# 96         0.526   0.840   11    -4.159     1       0.0342      0.002920
# 97         0.208   0.854    9    -4.553     1       0.1560      0.005710
# 98         0.293   0.946    1    -4.230     0       0.2770      0.031700
# 99         0.304   0.938    1    -4.331     1       0.2280      0.000568
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.000000    0.0816    0.100  171.447  audio_features
# 1           0.022800    0.0953    0.498  185.252  audio_features
# 2           0.000000    0.2100    0.478  100.059  audio_features
# 3           0.000000    0.0691    0.713  125.984  audio_features
# 4           0.000997    0.1090    0.567  126.020  audio_features
# ..               ...       ...      ...      ...             ...
# 95          0.000000    0.2600    0.590  185.604  audio_features
# 96          0.000000    0.2720    0.433   93.972  audio_features
# 97          0.000002    0.0876    0.114   87.436  audio_features
# 98          0.000000    0.4680    0.311  155.009  audio_features
# 99          0.012600    0.3200    0.377  142.244  audio_features
#
#                         id                                   uri  \
# 0   4xkOaSrkexMciUUogZKVTS  spotify:track:4xkOaSrkexMciUUogZKVTS
# 1   3fOc9x06lKJBhz435mInlH  spotify:track:3fOc9x06lKJBhz435mInlH
# 2   3Y96xd4Ce0J47dcalLrEC8  spotify:track:3Y96xd4Ce0J47dcalLrEC8
# 3   6tqFC1DIOphJkCwrjVzPmg  spotify:track:6tqFC1DIOphJkCwrjVzPmg
# 4   5bU4KX47KqtDKKaLM4QCzh  spotify:track:5bU4KX47KqtDKKaLM4QCzh
# ..                     ...                                   ...
# 95  4AtmALMF0y7ttIykE7Z1B0  spotify:track:4AtmALMF0y7ttIykE7Z1B0
# 96  0SqgZ5KpfX24W8ZeGzOle2  spotify:track:0SqgZ5KpfX24W8ZeGzOle2
# 97  04IgJXw7Wq1lDLefyMAUAC  spotify:track:04IgJXw7Wq1lDLefyMAUAC
# 98  2P5OwB19yivBQE1tHGGiv8  spotify:track:2P5OwB19yivBQE1tHGGiv8
# 99  5W4eJ7KPOmruHn8BJPnoaj  spotify:track:5W4eJ7KPOmruHn8BJPnoaj
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/4xkOaSrkexMc...
# 1   https://api.spotify.com/v1/tracks/3fOc9x06lKJB...
# 2   https://api.spotify.com/v1/tracks/3Y96xd4Ce0J4...
# 3   https://api.spotify.com/v1/tracks/6tqFC1DIOphJ...
# 4   https://api.spotify.com/v1/tracks/5bU4KX47KqtD...
# ..                                                ...
# 95  https://api.spotify.com/v1/tracks/4AtmALMF0y7t...
# 96  https://api.spotify.com/v1/tracks/0SqgZ5KpfX24...
# 97  https://api.spotify.com/v1/tracks/04IgJXw7Wq1l...
# 98  https://api.spotify.com/v1/tracks/2P5OwB19yivB...
# 99  https://api.spotify.com/v1/tracks/5W4eJ7KPOmru...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/4xkO...       297787
# 1   https://api.spotify.com/v1/audio-analysis/3fOc...       441133
# 2   https://api.spotify.com/v1/audio-analysis/3Y96...       204960
# 3   https://api.spotify.com/v1/audio-analysis/6tqF...       298360
# 4   https://api.spotify.com/v1/audio-analysis/5bU4...       186067
# ..                                                ...          ...
# 95  https://api.spotify.com/v1/audio-analysis/4Atm...       165035
# 96  https://api.spotify.com/v1/audio-analysis/0Sqg...       223493
# 97  https://api.spotify.com/v1/audio-analysis/04Ig...       203627
# 98  https://api.spotify.com/v1/audio-analysis/2P5O...       299355
# 99  https://api.spotify.com/v1/audio-analysis/5W4e...       223280
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# ..             ...
# 95               3
# 96               4
# 97               4
# 98               4
# 99               4
#
# [900 rows x 18 columns]
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.548   0.847    1    -3.237     1       0.1860      0.062200
# 1          0.249   0.949    2    -2.642     0       0.0678      0.001310
# 2          0.668   0.787    1    -4.226     1       0.0429      0.109000
# 3          0.805   0.918    9    -4.554     1       0.2120      0.049300
# 4          0.657   0.960    5    -3.524     0       0.0700      0.001690
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.569   0.440    5   -10.598     0       0.0341      0.579000
# 96         0.429   0.900    9    -5.870     1       0.0942      0.000478
# 97         0.495   0.808    3    -6.186     1       0.0315      0.002230
# 98         0.317   0.959    6    -5.283     1       0.0568      0.000008
# 99         0.688   0.880    0    -5.231     1       0.1990      0.067400
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.000000    0.0816    0.100  171.447  audio_features
# 1           0.022800    0.0953    0.498  185.252  audio_features
# 2           0.000000    0.2100    0.478  100.059  audio_features
# 3           0.000000    0.0691    0.713  125.984  audio_features
# 4           0.000997    0.1090    0.567  126.020  audio_features
# ..               ...       ...      ...      ...             ...
# 95          0.725000    0.1150    0.326  118.382  audio_features
# 96          0.825000    0.0952    0.599  135.173  audio_features
# 97          0.040700    0.9370    0.439  102.198  audio_features
# 98          0.009320    0.1240    0.565  194.992  audio_features
# 99          0.000089    0.3090    0.896  179.972  audio_features
#
#                         id                                   uri  \
# 0   4xkOaSrkexMciUUogZKVTS  spotify:track:4xkOaSrkexMciUUogZKVTS
# 1   3fOc9x06lKJBhz435mInlH  spotify:track:3fOc9x06lKJBhz435mInlH
# 2   3Y96xd4Ce0J47dcalLrEC8  spotify:track:3Y96xd4Ce0J47dcalLrEC8
# 3   6tqFC1DIOphJkCwrjVzPmg  spotify:track:6tqFC1DIOphJkCwrjVzPmg
# 4   5bU4KX47KqtDKKaLM4QCzh  spotify:track:5bU4KX47KqtDKKaLM4QCzh
# ..                     ...                                   ...
# 95  1ey9ub4AISvEmjM7tkoBh0  spotify:track:1ey9ub4AISvEmjM7tkoBh0
# 96  66BwWfwHYkoGSi6iUUj98I  spotify:track:66BwWfwHYkoGSi6iUUj98I
# 97  5LITE8LnYqAvc0RIyU1xWn  spotify:track:5LITE8LnYqAvc0RIyU1xWn
# 98  3yJk2ERDKdFHOXlpsR17o4  spotify:track:3yJk2ERDKdFHOXlpsR17o4
# 99  0XFYe43c3nkd8yPQ4hDGFs  spotify:track:0XFYe43c3nkd8yPQ4hDGFs
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/4xkOaSrkexMc...
# 1   https://api.spotify.com/v1/tracks/3fOc9x06lKJB...
# 2   https://api.spotify.com/v1/tracks/3Y96xd4Ce0J4...
# 3   https://api.spotify.com/v1/tracks/6tqFC1DIOphJ...
# 4   https://api.spotify.com/v1/tracks/5bU4KX47KqtD...
# ..                                                ...
# 95  https://api.spotify.com/v1/tracks/1ey9ub4AISvE...
# 96  https://api.spotify.com/v1/tracks/66BwWfwHYkoG...
# 97  https://api.spotify.com/v1/tracks/5LITE8LnYqAv...
# 98  https://api.spotify.com/v1/tracks/3yJk2ERDKdFH...
# 99  https://api.spotify.com/v1/tracks/0XFYe43c3nkd...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/4xkO...       297787
# 1   https://api.spotify.com/v1/audio-analysis/3fOc...       441133
# 2   https://api.spotify.com/v1/audio-analysis/3Y96...       204960
# 3   https://api.spotify.com/v1/audio-analysis/6tqF...       298360
# 4   https://api.spotify.com/v1/audio-analysis/5bU4...       186067
# ..                                                ...          ...
# 95  https://api.spotify.com/v1/audio-analysis/1ey9...       135693
# 96  https://api.spotify.com/v1/audio-analysis/66Bw...       163337
# 97  https://api.spotify.com/v1/audio-analysis/5LIT...       218753
# 98  https://api.spotify.com/v1/audio-analysis/3yJk...       183093
# 99  https://api.spotify.com/v1/audio-analysis/0XFY...       153947
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# ..             ...
# 95               4
# 96               4
# 97               3
# 98               4
# 99               4
#
# [1000 rows x 18 columns]
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.548   0.847    1    -3.237     1       0.1860      0.062200
# 1          0.249   0.949    2    -2.642     0       0.0678      0.001310
# 2          0.668   0.787    1    -4.226     1       0.0429      0.109000
# 3          0.805   0.918    9    -4.554     1       0.2120      0.049300
# 4          0.657   0.960    5    -3.524     0       0.0700      0.001690
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.386   0.895   10    -4.851     1       0.0608      0.002020
# 96         0.449   0.962    0    -3.774     1       0.1830      0.002320
# 97         0.382   0.971    2    -5.078     1       0.0697      0.001150
# 98         0.438   0.682    3    -6.797     1       0.0335      0.254000
# 99         0.454   0.914    7    -2.936     1       0.0812      0.000041
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.000000    0.0816    0.100  171.447  audio_features
# 1           0.022800    0.0953    0.498  185.252  audio_features
# 2           0.000000    0.2100    0.478  100.059  audio_features
# 3           0.000000    0.0691    0.713  125.984  audio_features
# 4           0.000997    0.1090    0.567  126.020  audio_features
# ..               ...       ...      ...      ...             ...
# 95          0.000023    0.1770    0.191   76.967  audio_features
# 96          0.000021    0.3100    0.466  104.316  audio_features
# 97          0.000000    0.2360    0.301   96.054  audio_features
# 98          0.155000    0.0451    0.420  110.646  audio_features
# 99          0.072400    0.6120    0.636  173.799  audio_features
#
#                         id                                   uri  \
# 0   4xkOaSrkexMciUUogZKVTS  spotify:track:4xkOaSrkexMciUUogZKVTS
# 1   3fOc9x06lKJBhz435mInlH  spotify:track:3fOc9x06lKJBhz435mInlH
# 2   3Y96xd4Ce0J47dcalLrEC8  spotify:track:3Y96xd4Ce0J47dcalLrEC8
# 3   6tqFC1DIOphJkCwrjVzPmg  spotify:track:6tqFC1DIOphJkCwrjVzPmg
# 4   5bU4KX47KqtDKKaLM4QCzh  spotify:track:5bU4KX47KqtDKKaLM4QCzh
# ..                     ...                                   ...
# 95  6ApS4uU27SmWkryPXwGZ8x  spotify:track:6ApS4uU27SmWkryPXwGZ8x
# 96  1hKHFbVgr2UnnwpzkbRrZB  spotify:track:1hKHFbVgr2UnnwpzkbRrZB
# 97  0LMQpAwXJ2qMRYoHNHQCip  spotify:track:0LMQpAwXJ2qMRYoHNHQCip
# 98  6Z28TjDNV65WracUmCEJIY  spotify:track:6Z28TjDNV65WracUmCEJIY
# 99  0UwrQ4tgKCsLQoNUK9Dvrl  spotify:track:0UwrQ4tgKCsLQoNUK9Dvrl
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/4xkOaSrkexMc...
# 1   https://api.spotify.com/v1/tracks/3fOc9x06lKJB...
# 2   https://api.spotify.com/v1/tracks/3Y96xd4Ce0J4...
# 3   https://api.spotify.com/v1/tracks/6tqFC1DIOphJ...
# 4   https://api.spotify.com/v1/tracks/5bU4KX47KqtD...
# ..                                                ...
# 95  https://api.spotify.com/v1/tracks/6ApS4uU27SmW...
# 96  https://api.spotify.com/v1/tracks/1hKHFbVgr2Un...
# 97  https://api.spotify.com/v1/tracks/0LMQpAwXJ2qM...
# 98  https://api.spotify.com/v1/tracks/6Z28TjDNV65W...
# 99  https://api.spotify.com/v1/tracks/0UwrQ4tgKCsL...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/4xkO...       297787
# 1   https://api.spotify.com/v1/audio-analysis/3fOc...       441133
# 2   https://api.spotify.com/v1/audio-analysis/3Y96...       204960
# 3   https://api.spotify.com/v1/audio-analysis/6tqF...       298360
# 4   https://api.spotify.com/v1/audio-analysis/5bU4...       186067
# ..                                                ...          ...
# 95  https://api.spotify.com/v1/audio-analysis/6ApS...       343667
# 96  https://api.spotify.com/v1/audio-analysis/1hKH...       194920
# 97  https://api.spotify.com/v1/audio-analysis/0LMQ...       191565
# 98  https://api.spotify.com/v1/audio-analysis/6Z28...       220413
# 99  https://api.spotify.com/v1/audio-analysis/0Uwr...       161820
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# ..             ...
# 95               4
# 96               4
# 97               3
# 98               4
# 99               4
#
# [1100 rows x 18 columns]
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.548   0.847    1    -3.237     1       0.1860      0.062200
# 1          0.249   0.949    2    -2.642     0       0.0678      0.001310
# 2          0.668   0.787    1    -4.226     1       0.0429      0.109000
# 3          0.805   0.918    9    -4.554     1       0.2120      0.049300
# 4          0.657   0.960    5    -3.524     0       0.0700      0.001690
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.316   0.844    7    -4.942     1       0.0451      0.000010
# 96         0.473   0.860   11    -6.518     0       0.1210      0.005160
# 97         0.511   0.914    8    -5.310     0       0.0457      0.000106
# 98         0.492   0.947    1    -5.970     1       0.0433      0.000003
# 99         0.436   0.825    9    -4.207     0       0.0264      0.000505
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.000000    0.0816    0.100  171.447  audio_features
# 1           0.022800    0.0953    0.498  185.252  audio_features
# 2           0.000000    0.2100    0.478  100.059  audio_features
# 3           0.000000    0.0691    0.713  125.984  audio_features
# 4           0.000997    0.1090    0.567  126.020  audio_features
# ..               ...       ...      ...      ...             ...
# 95          0.103000    0.1400    0.439   98.911  audio_features
# 96          0.000000    0.7600    0.210  138.891  audio_features
# 97          0.000970    0.1950    0.393   99.011  audio_features
# 98          0.756000    0.3190    0.212  120.036  audio_features
# 99          0.000001    0.3080    0.511  160.274  audio_features
#
#                         id                                   uri  \
# 0   4xkOaSrkexMciUUogZKVTS  spotify:track:4xkOaSrkexMciUUogZKVTS
# 1   3fOc9x06lKJBhz435mInlH  spotify:track:3fOc9x06lKJBhz435mInlH
# 2   3Y96xd4Ce0J47dcalLrEC8  spotify:track:3Y96xd4Ce0J47dcalLrEC8
# 3   6tqFC1DIOphJkCwrjVzPmg  spotify:track:6tqFC1DIOphJkCwrjVzPmg
# 4   5bU4KX47KqtDKKaLM4QCzh  spotify:track:5bU4KX47KqtDKKaLM4QCzh
# ..                     ...                                   ...
# 95  37mcskMYPUoi0ZlqAPBByr  spotify:track:37mcskMYPUoi0ZlqAPBByr
# 96  2QXBh408EhthzKXKO8Lbqk  spotify:track:2QXBh408EhthzKXKO8Lbqk
# 97  08EI81e55Lcqg2ZelJOXcG  spotify:track:08EI81e55Lcqg2ZelJOXcG
# 98  7wIIyXUVvcNOKTSXlNIwGg  spotify:track:7wIIyXUVvcNOKTSXlNIwGg
# 99  7nJJa0qfRnbn2XQKxVgLrV  spotify:track:7nJJa0qfRnbn2XQKxVgLrV
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/4xkOaSrkexMc...
# 1   https://api.spotify.com/v1/tracks/3fOc9x06lKJB...
# 2   https://api.spotify.com/v1/tracks/3Y96xd4Ce0J4...
# 3   https://api.spotify.com/v1/tracks/6tqFC1DIOphJ...
# 4   https://api.spotify.com/v1/tracks/5bU4KX47KqtD...
# ..                                                ...
# 95  https://api.spotify.com/v1/tracks/37mcskMYPUoi...
# 96  https://api.spotify.com/v1/tracks/2QXBh408Ehth...
# 97  https://api.spotify.com/v1/tracks/08EI81e55Lcq...
# 98  https://api.spotify.com/v1/tracks/7wIIyXUVvcNO...
# 99  https://api.spotify.com/v1/tracks/7nJJa0qfRnbn...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/4xkO...       297787
# 1   https://api.spotify.com/v1/audio-analysis/3fOc...       441133
# 2   https://api.spotify.com/v1/audio-analysis/3Y96...       204960
# 3   https://api.spotify.com/v1/audio-analysis/6tqF...       298360
# 4   https://api.spotify.com/v1/audio-analysis/5bU4...       186067
# ..                                                ...          ...
# 95  https://api.spotify.com/v1/audio-analysis/37mc...       211160
# 96  https://api.spotify.com/v1/audio-analysis/2QXB...       268267
# 97  https://api.spotify.com/v1/audio-analysis/08EI...       248413
# 98  https://api.spotify.com/v1/audio-analysis/7wII...       285667
# 99  https://api.spotify.com/v1/audio-analysis/7nJJ...       261573
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# ..             ...
# 95               4
# 96               4
# 97               4
# 98               4
# 99               4
#
# [1200 rows x 18 columns]
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# ...
# 96          0.954000    0.3070   0.5960  118.476  audio_features
# 97          0.134000    0.1480   0.2440  175.670  audio_features
# 98          0.000116    0.2710   0.2830   83.700  audio_features
# 99          0.162000    0.1380   0.0568   86.878  audio_features
#
#                         id                                   uri  \
# 0   4xkOaSrkexMciUUogZKVTS  spotify:track:4xkOaSrkexMciUUogZKVTS
# 1   3fOc9x06lKJBhz435mInlH  spotify:track:3fOc9x06lKJBhz435mInlH
# 2   3Y96xd4Ce0J47dcalLrEC8  spotify:track:3Y96xd4Ce0J47dcalLrEC8
# 3   6tqFC1DIOphJkCwrjVzPmg  spotify:track:6tqFC1DIOphJkCwrjVzPmg
# 4   5bU4KX47KqtDKKaLM4QCzh  spotify:track:5bU4KX47KqtDKKaLM4QCzh
# ..                     ...                                   ...
# 95  7dXjq4Wp7eEPsGVsOhRQDQ  spotify:track:7dXjq4Wp7eEPsGVsOhRQDQ
# 96  5S2EJlxpRjHlbnUTqnVrxA  spotify:track:5S2EJlxpRjHlbnUTqnVrxA
# 97  4NEvzBSsNb3VHdkAa0HSjm  spotify:track:4NEvzBSsNb3VHdkAa0HSjm
# 98  7et15OpHPPmf6PVgSNWlJv  spotify:track:7et15OpHPPmf6PVgSNWlJv
# 99  4iX4E9GuILdXfgzR01Xjhw  spotify:track:4iX4E9GuILdXfgzR01Xjhw
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/4xkOaSrkexMc...
# 1   https://api.spotify.com/v1/tracks/3fOc9x06lKJB...
# 2   https://api.spotify.com/v1/tracks/3Y96xd4Ce0J4...
# 3   https://api.spotify.com/v1/tracks/6tqFC1DIOphJ...
# 4   https://api.spotify.com/v1/tracks/5bU4KX47KqtD...
# ..                                                ...
# 95  https://api.spotify.com/v1/tracks/7dXjq4Wp7eEP...
# 96  https://api.spotify.com/v1/tracks/5S2EJlxpRjHl...
# 97  https://api.spotify.com/v1/tracks/4NEvzBSsNb3V...
# 98  https://api.spotify.com/v1/tracks/7et15OpHPPmf...
# 99  https://api.spotify.com/v1/tracks/4iX4E9GuILdX...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/4xkO...       297787
# 1   https://api.spotify.com/v1/audio-analysis/3fOc...       441133
# 2   https://api.spotify.com/v1/audio-analysis/3Y96...       204960
# 3   https://api.spotify.com/v1/audio-analysis/6tqF...       298360
# 4   https://api.spotify.com/v1/audio-analysis/5bU4...       186067
# ..                                                ...          ...
# 95  https://api.spotify.com/v1/audio-analysis/7dXj...       490133
# 96  https://api.spotify.com/v1/audio-analysis/5S2E...       326120
# 97  https://api.spotify.com/v1/audio-analysis/4NEv...       206600
# 98  https://api.spotify.com/v1/audio-analysis/7et1...       174747
# 99  https://api.spotify.com/v1/audio-analysis/4iX4...        28480
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# ..             ...
# 95               3
# 96               4
# 97               4
# 98               5
# 99               4
#
# [61400 rows x 18 columns]
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.548  0.8470    1    -3.237     1       0.1860       0.06220
# 1          0.249  0.9490    2    -2.642     0       0.0678       0.00131
# 2          0.668  0.7870    1    -4.226     1       0.0429       0.10900
# 3          0.805  0.9180    9    -4.554     1       0.2120       0.04930
# 4          0.657  0.9600    5    -3.524     0       0.0700       0.00169
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.391  0.4190    2   -10.989     1       0.0280       0.71000
# 96         0.728  0.2510    2   -11.641     1       0.0345       0.88700
# 97         0.552  0.4500    0    -5.804     1       0.0238       0.75800
# 98         0.355  0.0802    5   -25.423     0       0.0502       0.84100
# 99         0.183  0.0380    7   -22.294     1       0.0391       0.98600
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.000000    0.0816   0.1000  171.447  audio_features
# 1           0.022800    0.0953   0.4980  185.252  audio_features
# 2           0.000000    0.2100   0.4780  100.059  audio_features
# 3           0.000000    0.0691   0.7130  125.984  audio_features
# 4           0.000997    0.1090   0.5670  126.020  audio_features
# ..               ...       ...      ...      ...             ...
# 95          0.120000    0.1110   0.5150  142.978  audio_features
# 96          0.004340    0.1230   0.3240   96.006  audio_features
# 97          0.000000    0.2680   0.4820   85.972  audio_features
# 98          0.379000    0.1170   0.0522  182.922  audio_features
# 99          0.860000    0.1140   0.0375   76.832  audio_features
#
#                         id                                   uri  \
# 0   4xkOaSrkexMciUUogZKVTS  spotify:track:4xkOaSrkexMciUUogZKVTS
# 1   3fOc9x06lKJBhz435mInlH  spotify:track:3fOc9x06lKJBhz435mInlH
# 2   3Y96xd4Ce0J47dcalLrEC8  spotify:track:3Y96xd4Ce0J47dcalLrEC8
# 3   6tqFC1DIOphJkCwrjVzPmg  spotify:track:6tqFC1DIOphJkCwrjVzPmg
# 4   5bU4KX47KqtDKKaLM4QCzh  spotify:track:5bU4KX47KqtDKKaLM4QCzh
# ..                     ...                                   ...
# 95  3xSxoe7T4O2Fi7frL6WXe8  spotify:track:3xSxoe7T4O2Fi7frL6WXe8
# 96  7eisXk579IdhmSA5EBn6cE  spotify:track:7eisXk579IdhmSA5EBn6cE
# 97  0RbxW53rdQ5NoOw01OWvH7  spotify:track:0RbxW53rdQ5NoOw01OWvH7
# 98  30dydXgktpecBryXxT71XD  spotify:track:30dydXgktpecBryXxT71XD
# 99  6N2aMjBXkTFpOOFWGoJ6LZ  spotify:track:6N2aMjBXkTFpOOFWGoJ6LZ
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/4xkOaSrkexMc...
# 1   https://api.spotify.com/v1/tracks/3fOc9x06lKJB...
# 2   https://api.spotify.com/v1/tracks/3Y96xd4Ce0J4...
# 3   https://api.spotify.com/v1/tracks/6tqFC1DIOphJ...
# 4   https://api.spotify.com/v1/tracks/5bU4KX47KqtD...
# ..                                                ...
# 95  https://api.spotify.com/v1/tracks/3xSxoe7T4O2F...
# 96  https://api.spotify.com/v1/tracks/7eisXk579Idh...
# 97  https://api.spotify.com/v1/tracks/0RbxW53rdQ5N...
# 98  https://api.spotify.com/v1/tracks/30dydXgktpec...
# 99  https://api.spotify.com/v1/tracks/6N2aMjBXkTFp...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/4xkO...       297787
# 1   https://api.spotify.com/v1/audio-analysis/3fOc...       441133
# 2   https://api.spotify.com/v1/audio-analysis/3Y96...       204960
# 3   https://api.spotify.com/v1/audio-analysis/6tqF...       298360
# 4   https://api.spotify.com/v1/audio-analysis/5bU4...       186067
# ..                                                ...          ...
# 95  https://api.spotify.com/v1/audio-analysis/3xSx...       229894
# 96  https://api.spotify.com/v1/audio-analysis/7eis...       234933
# 97  https://api.spotify.com/v1/audio-analysis/0Rbx...       230080
# 98  https://api.spotify.com/v1/audio-analysis/30dy...       281560
# 99  https://api.spotify.com/v1/audio-analysis/6N2a...       125987
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# ..             ...
# 95               3
# 96               4
# 97               3
# 98               1
# 99               4
#
# [61500 rows x 18 columns]
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.548   0.847    1    -3.237     1       0.1860       0.06220
# 1          0.249   0.949    2    -2.642     0       0.0678       0.00131
# 2          0.668   0.787    1    -4.226     1       0.0429       0.10900
# 3          0.805   0.918    9    -4.554     1       0.2120       0.04930
# 4          0.657   0.960    5    -3.524     0       0.0700       0.00169
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.815   0.268    0   -16.866     1       0.0447       0.69500
# 96         0.629   0.655    9    -7.685     1       0.0401       0.51100
# 97         0.488   0.342    2    -9.438     1       0.1200       0.84600
# 98         0.706   0.456    0   -10.180     1       0.0267       0.42800
# 99         0.620   0.733    0    -7.572     1       0.0357       0.83300
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.000000    0.0816    0.100  171.447  audio_features
# 1           0.022800    0.0953    0.498  185.252  audio_features
# 2           0.000000    0.2100    0.478  100.059  audio_features
# 3           0.000000    0.0691    0.713  125.984  audio_features
# 4           0.000997    0.1090    0.567  126.020  audio_features
# ..               ...       ...      ...      ...             ...
# 95          0.858000    0.1290    0.700  118.806  audio_features
# 96          0.000109    0.1070    0.176  123.765  audio_features
# 97          0.000000    0.3910    0.480  116.710  audio_features
# 98          0.114000    0.2680    0.577  127.920  audio_features
# 99          0.220000    0.0862    0.961   78.123  audio_features
#
#                         id                                   uri  \
# 0   4xkOaSrkexMciUUogZKVTS  spotify:track:4xkOaSrkexMciUUogZKVTS
# 1   3fOc9x06lKJBhz435mInlH  spotify:track:3fOc9x06lKJBhz435mInlH
# 2   3Y96xd4Ce0J47dcalLrEC8  spotify:track:3Y96xd4Ce0J47dcalLrEC8
# 3   6tqFC1DIOphJkCwrjVzPmg  spotify:track:6tqFC1DIOphJkCwrjVzPmg
# 4   5bU4KX47KqtDKKaLM4QCzh  spotify:track:5bU4KX47KqtDKKaLM4QCzh
# ..                     ...                                   ...
# 95  45H5qttaXmyycyA1EafVmJ  spotify:track:45H5qttaXmyycyA1EafVmJ
# 96  13cs44TwyzAGL73OPYqjbB  spotify:track:13cs44TwyzAGL73OPYqjbB
# 97  2ubBqnxBNP8QpoGQ77NPuO  spotify:track:2ubBqnxBNP8QpoGQ77NPuO
# 98  7piTK9aPEBxKSXdmohLyo5  spotify:track:7piTK9aPEBxKSXdmohLyo5
# 99  5TApkqwgrg2A7SJY9A8V7p  spotify:track:5TApkqwgrg2A7SJY9A8V7p
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/4xkOaSrkexMc...
# 1   https://api.spotify.com/v1/tracks/3fOc9x06lKJB...
# 2   https://api.spotify.com/v1/tracks/3Y96xd4Ce0J4...
# 3   https://api.spotify.com/v1/tracks/6tqFC1DIOphJ...
# 4   https://api.spotify.com/v1/tracks/5bU4KX47KqtD...
# ..                                                ...
# 95  https://api.spotify.com/v1/tracks/45H5qttaXmyy...
# 96  https://api.spotify.com/v1/tracks/13cs44TwyzAG...
# 97  https://api.spotify.com/v1/tracks/2ubBqnxBNP8Q...
# 98  https://api.spotify.com/v1/tracks/7piTK9aPEBxK...
# 99  https://api.spotify.com/v1/tracks/5TApkqwgrg2A...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/4xkO...       297787
# 1   https://api.spotify.com/v1/audio-analysis/3fOc...       441133
# 2   https://api.spotify.com/v1/audio-analysis/3Y96...       204960
# 3   https://api.spotify.com/v1/audio-analysis/6tqF...       298360
# 4   https://api.spotify.com/v1/audio-analysis/5bU4...       186067
# ..                                                ...          ...
# 95  https://api.spotify.com/v1/audio-analysis/45H5...       191467
# 96  https://api.spotify.com/v1/audio-analysis/13cs...       194933
# 97  https://api.spotify.com/v1/audio-analysis/2ubB...       260000
# 98  https://api.spotify.com/v1/audio-analysis/7piT...       167400
# 99  https://api.spotify.com/v1/audio-analysis/5TAp...       218720
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# ..             ...
# 95               4
# 96               4
# 97               4
# 98               4
# 99               4
#
# [61600 rows x 18 columns]
# 61600
# LAST
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.548   0.847    1    -3.237     1       0.1860       0.06220
# 1          0.249   0.949    2    -2.642     0       0.0678       0.00131
# 2          0.668   0.787    1    -4.226     1       0.0429       0.10900
# 3          0.805   0.918    9    -4.554     1       0.2120       0.04930
# 4          0.657   0.960    5    -3.524     0       0.0700       0.00169
# ..           ...     ...  ...       ...   ...          ...           ...
# 22         0.396   0.915    0    -5.126     0       0.1560       0.03340
# 23         0.244   0.866    2    -5.774     0       0.0674       0.00433
# 24         0.236   0.107   10   -20.091     0       0.0344       0.90100
# 25         0.542   0.909    2    -8.977     0       0.1230       0.07180
# 26         0.495   0.291    0   -11.355     1       0.0280       0.72700
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.000000    0.0816   0.1000  171.447  audio_features
# 1           0.022800    0.0953   0.4980  185.252  audio_features
# 2           0.000000    0.2100   0.4780  100.059  audio_features
# 3           0.000000    0.0691   0.7130  125.984  audio_features
# 4           0.000997    0.1090   0.5670  126.020  audio_features
# ..               ...       ...      ...      ...             ...
# 22          0.000000    0.1350   0.0734  167.996  audio_features
# 23          0.072200    0.0782   0.3400  144.844  audio_features
# 24          0.748000    0.1120   0.0720   79.476  audio_features
# 25          0.817000    0.1250   0.0552  160.011  audio_features
# 26          0.913000    0.0927   0.1700   96.970  audio_features
#
#                         id                                   uri  \
# 0   4xkOaSrkexMciUUogZKVTS  spotify:track:4xkOaSrkexMciUUogZKVTS
# 1   3fOc9x06lKJBhz435mInlH  spotify:track:3fOc9x06lKJBhz435mInlH
# 2   3Y96xd4Ce0J47dcalLrEC8  spotify:track:3Y96xd4Ce0J47dcalLrEC8
# 3   6tqFC1DIOphJkCwrjVzPmg  spotify:track:6tqFC1DIOphJkCwrjVzPmg
# 4   5bU4KX47KqtDKKaLM4QCzh  spotify:track:5bU4KX47KqtDKKaLM4QCzh
# ..                     ...                                   ...
# 22  2bRIsZ92JRKlvQOZlyR9CO  spotify:track:2bRIsZ92JRKlvQOZlyR9CO
# 23  7o3Np7cho9cBCrNDokxzYC  spotify:track:7o3Np7cho9cBCrNDokxzYC
# 24  4fVObxldDzxxRD6a5Eth9s  spotify:track:4fVObxldDzxxRD6a5Eth9s
# 25  5WxwRwUQ4R4L46VEm3213y  spotify:track:5WxwRwUQ4R4L46VEm3213y
# 26  14BYEOeRb3jzglJmKX8eM2  spotify:track:14BYEOeRb3jzglJmKX8eM2
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/4xkOaSrkexMc...
# 1   https://api.spotify.com/v1/tracks/3fOc9x06lKJB...
# 2   https://api.spotify.com/v1/tracks/3Y96xd4Ce0J4...
# 3   https://api.spotify.com/v1/tracks/6tqFC1DIOphJ...
# 4   https://api.spotify.com/v1/tracks/5bU4KX47KqtD...
# ..                                                ...
# 22  https://api.spotify.com/v1/tracks/2bRIsZ92JRKl...
# 23  https://api.spotify.com/v1/tracks/7o3Np7cho9cB...
# 24  https://api.spotify.com/v1/tracks/4fVObxldDzxx...
# 25  https://api.spotify.com/v1/tracks/5WxwRwUQ4R4L...
# 26  https://api.spotify.com/v1/tracks/14BYEOeRb3jz...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/4xkO...       297787
# 1   https://api.spotify.com/v1/audio-analysis/3fOc...       441133
# 2   https://api.spotify.com/v1/audio-analysis/3Y96...       204960
# 3   https://api.spotify.com/v1/audio-analysis/6tqF...       298360
# 4   https://api.spotify.com/v1/audio-analysis/5bU4...       186067
# ..                                                ...          ...
# 22  https://api.spotify.com/v1/audio-analysis/2bRI...       258373
# 23  https://api.spotify.com/v1/audio-analysis/7o3N...       324000
# 24  https://api.spotify.com/v1/audio-analysis/4fVO...       516280
# 25  https://api.spotify.com/v1/audio-analysis/5Wxw...       324258
# 26  https://api.spotify.com/v1/audio-analysis/14BY...       268440
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# ..             ...
# 22               4
# 23               3
# 24               4
# 25               4
# 26               4
#
# [61627 rows x 18 columns]

# %%
print(data.shape)
print(audio_data.shape)
audio_data = audio_data.reset_index(drop=True)

# combine original dataset containing titles/artists with the pulled audio features

full_data = pd.concat((data, audio_data), axis=1)
full_data = full_data.reset_index(drop=True)

audio_data.to_csv("audio_feat.csv")

full_data.to_csv("full_data.csv")
# Out:
# (61627, 4)
# (61627, 18)

# %% [markdown]
# # Removing Duplicate Tags
#
# full_data.csv contains the cleaned data w/ pulled audio features from Spotify.
#
# The code below then cuts songs that are associated with multiple tags, leaving only songs w/ a singular emotion tag.

# %%
full_data = pd.read_csv("full_data.csv")
full_data = full_data.drop("Unnamed: 0", axis=1)

# get only rows where the "seeds"/tags columns does not contain a "," that indicated multiple tags
single_tags = full_data[full_data["seeds"].str.contains(",") == False]

# the list of the different tags and # of occurrences is written to tags.csv
# full dataset with only single tags is written to single_tags.csv
single_tags["seeds"].value_counts().to_csv("tags.csv")
single_tags.to_csv("single_tags.csv")

# %%
print(full_data.shape)
print(single_tags.shape)

print(single_tags["seeds"].shape)

# this only cuts about 13000 from the dataset. 

# PROBLEM: too many labels.
# there are about 2560 different labels
# and each label accounts for at maximum 1.5% of the data points
# Out:
# (61627, 22)
# (48390, 22)
# (48390,)

# %% [markdown]
# # Creating CSV of Features for Single Tags

# %%
relevant_data_single_tags = single_tags.drop(["track", "artist", "seeds", "spotify_id", "type", "id", "uri", "track_href", "analysis_url", "duration_ms"], axis=1)
print(relevant_data_single_tags)

relevant_data_single_tags.to_csv("relevant_features_single_tags.csv")
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.548   0.847    1    -3.237     1       0.1860      0.062200
# 1             0.249   0.949    2    -2.642     0       0.0678      0.001310
# 2             0.668   0.787    1    -4.226     1       0.0429      0.109000
# 4             0.657   0.960    5    -3.524     0       0.0700      0.001690
# 5             0.431   0.962    6    -3.269     1       0.0789      0.000008
# ...             ...     ...  ...       ...   ...          ...           ...
# 61622         0.396   0.915    0    -5.126     0       0.1560      0.033400
# 61623         0.244   0.866    2    -5.774     0       0.0674      0.004330
# 61624         0.236   0.107   10   -20.091     0       0.0344      0.901000
# 61625         0.542   0.909    2    -8.977     0       0.1230      0.071800
# 61626         0.495   0.291    0   -11.355     1       0.0280      0.727000
#
#        instrumentalness  liveness  valence    tempo  time_signature
# 0              0.000000    0.0816   0.1000  171.447               4
# 1              0.022800    0.0953   0.4980  185.252               4
# 2              0.000000    0.2100   0.4780  100.059               4
# 4              0.000997    0.1090   0.5670  126.020               4
# 5              0.000005    0.3210   0.5850  156.103               4
# ...                 ...       ...      ...      ...             ...
# 61622          0.000000    0.1350   0.0734  167.996               4
# 61623          0.072200    0.0782   0.3400  144.844               3
# 61624          0.748000    0.1120   0.0720   79.476               4
# 61625          0.817000    0.1250   0.0552  160.011               4
# 61626          0.913000    0.0927   0.1700   96.970               4
#
# [48390 rows x 12 columns]

# %% [markdown]
# # Initial PCA Analysis

# %%
# perform PCA on full_data (for unsupervised learning)
# drop irrelevant columns to get only relevant features 
relevant_data = full_data.drop(["track", "artist", "seeds", "spotify_id", "type", "id", "uri", "track_href", "analysis_url", "duration_ms"], axis=1)
print(relevant_data.shape)

relevant_data.to_csv("features_only.csv")

print(relevant_data.columns)

scaler = StandardScaler()
scaler.fit(relevant_data.to_numpy())
scaled_data = scaler.transform(relevant_data.to_numpy())

# pca with all 12 componenets (no features removed)
pca_full = PCA(12)
pca_full.fit(scaled_data)
pca_full_data = pca_full.transform(scaled_data)

# prints the percentage of variance attributed/explained by each component
print(pca_full.explained_variance_ratio_)

# prints the principal components (eigenvectors)
# see how much each original feature contributes to each component
print(pca_full.components_)
# Out:
# (61627, 12)
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'time_signature'],
#       dtype='object')
# [0.25852876 0.11352705 0.09887135 0.09709431 0.08114961 0.07430625
#  0.07126963 0.06620282 0.06305546 0.03538144 0.02872126 0.01189205]
# [[-2.71376318e-01 -4.91197283e-01 -2.60754062e-02 -4.77282660e-01
#   -5.01374101e-03 -1.22084970e-01  4.38932157e-01  2.37321677e-01
#   -1.12023665e-01 -3.54964914e-01 -1.63473538e-01 -1.65576491e-01]
#  [-5.93338512e-01  2.85677089e-01  2.89767506e-02  1.70698389e-01
#   -8.29119744e-02 -6.26395174e-02 -2.80481147e-01  3.05583785e-01
#    2.46985388e-01 -4.39007180e-01  2.85135797e-01 -1.35939994e-01]
#  [ 8.58634334e-02  1.42282930e-03  6.44998286e-01 -6.58323292e-02
#   -6.75323034e-01  2.50451146e-01  1.97411423e-02  9.80832646e-02
#    1.23890346e-01 -1.13856203e-04 -1.60910734e-01  4.72297541e-02]
#  [-6.12362988e-02 -3.03506694e-02 -1.66545236e-01 -6.90313685e-02
#    1.85338791e-01  6.33460970e-01  1.56410515e-01 -2.07116637e-01
#    6.34724290e-01 -1.78367300e-02 -1.39192984e-01 -1.93064051e-01]
#  [ 3.02606548e-03 -6.87830888e-02  2.24490693e-01  2.84639293e-02
#   -2.22594642e-02  2.61615752e-02  8.53446771e-02 -3.09604703e-01
#   -2.05008680e-01  1.27786473e-01  4.66855110e-01 -7.50615168e-01]
#  [-1.54082413e-01  4.84051455e-02  1.41282798e-01  2.54062913e-01
#    4.26870713e-02 -3.64881503e-01 -1.00489599e-01 -4.29366321e-01
#    5.44973591e-02 -1.69198846e-01 -6.76515463e-01 -2.65934354e-01]
#  [ 1.85016774e-01  1.24152295e-01 -5.64999004e-01  3.49150666e-02
#   -4.23272740e-01  1.23720892e-01 -1.54357998e-01  3.35772957e-01
#   -1.64952797e-01  6.22605946e-02 -2.79386969e-01 -4.35583101e-01]
#  [ 1.22941510e-01  1.41903143e-01  4.03804484e-01 -3.37387945e-02
#    5.64175453e-01  2.01673974e-01 -1.59586952e-01  5.10849677e-01
#   -1.65335219e-01  7.34069281e-02 -2.59142981e-01 -2.35098698e-01]
#  [-2.01837143e-01  2.85750529e-02 -4.03735467e-02  1.17313202e-01
#    6.69971329e-03  5.62549157e-01 -6.31229916e-02 -2.73046902e-01
#   -6.23201368e-01 -3.49300911e-01 -7.05391604e-02  1.80666587e-01]
#  [-6.50079848e-01  1.60879376e-01 -1.81504421e-02 -4.79695894e-02
#   -5.30594382e-02  4.81053071e-02  2.00042373e-01  3.45928513e-02
#   -1.32727969e-01  6.79603587e-01 -1.43451957e-01  4.98421935e-02]
#  [-1.06080242e-01 -1.59535211e-01 -1.02338014e-02 -6.23201452e-01
#   -5.14111900e-03  6.30783839e-03 -7.20381256e-01 -2.05736215e-01
#    1.59835074e-02  1.13860586e-01 -1.53186755e-02 -3.68590738e-03]
#  [ 1.24460690e-01  7.62506384e-01 -4.15792122e-03 -5.11668888e-01
#    5.54557955e-03 -9.24949690e-02  2.72374829e-01 -1.60559326e-01
#   -4.92885637e-02 -1.72903032e-01 -8.89385065e-03 -1.77164769e-02]]
